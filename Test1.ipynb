# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesj14/Python-and-Gen-AI/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Please enter your name: ")
print(f"Hello, World! My name is {name}.")
# Out:
# Please enter your name: jes
# Hello, World! My name is jes.

# %% [markdown]
# hello jeswin
